# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# list

cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name 
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description" : city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bathsheba
# Processing Record 2 of Set 1 | hofn
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | oranjemund
# Processing Record 5 of Set 1 | cairns
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | plerin
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | saint-tite
# Processing Record 10 of Set 1 | wajid
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | lagoa
# Processing Record 14 of Set 1 | hit
# Processing Record 15 of Set 1 | tecpan
# Processing Record 16 of Set 1 | garoua boulai
# Processing Record 17 of Set 1 | nehe
# Processing Record 18 of Set 1 | leshukonskoye
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | geresk
# City not found. Skipping...
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | havoysund
# Processing Record 25 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | pangnirtung
# Processing Record 29 of Set 1 | vao
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | lavrentiya
# Processing Record 32 of Set 1 | saint-augustin
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | nome
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | katsuura
# Processing Record 38 of Set 1 | jijiang
# Processing Record 39 of Set 1 | tomatlan
# Processing Record 40 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | walvis bay
# Processing Record 43 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 1 | saint-denis
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | karakol
# Processing Record 47 of Set 1 | alice springs
# Processing Record 48 of Set 1 | sompeta
# Processing Record 49 of Set 1 | skaerbaek
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | christchurch
# Processing Record 4 of Set 2 | abha
# Processing Record 5 of Set 2 | vila franca do campo
# Processing Record 6 of Set 2 | kualakapuas
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | petatlan
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | saldanha
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | abidjan
# Processing Record 13 of Set 2 | berlevag
# Processing Record 14 of Set 2 | sundargarh
# Processing Record 15 of Set 2 | praia da vitoria
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | buala
# Processing Record 20 of Set 2 | sinnamary
# Processing Record 21 of Set 2 | hambantota
# Processing Record 22 of Set 2 | vostok
# Processing Record 23 of Set 2 | fontaine
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 26 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | amqui
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | novikovo
# Processing Record 31 of Set 2 | murgab
# Processing Record 32 of Set 2 | vestmannaeyjar
# Processing Record 33 of Set 2 | yelizovo
# Processing Record 34 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 2 | ancud
# Processing Record 36 of Set 2 | chamba
# Processing Record 37 of Set 2 | winsum
# Processing Record 38 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | san patricio
# Processing Record 41 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | kindersley
# Processing Record 45 of Set 2 | iralaya
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | phayao
# Processing Record 48 of Set 2 | sirjan
# Processing Record 49 of Set 2 | pacific grove
# Processing Record 50 of Set 2 | okhotsk
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | santa cruz cabralia
# Processing Record 3 of Set 3 | taoudenni
# Processing Record 4 of Set 3 | hutang
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | iskateley
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | awjilah
# Processing Record 9 of Set 3 | rzhev
# Processing Record 10 of Set 3 | margate
# Processing Record 11 of Set 3 | yuci
# Processing Record 12 of Set 3 | aykhal
# Processing Record 13 of Set 3 | kununurra
# Processing Record 14 of Set 3 | sendafa
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | smolensk
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | kalianget
# Processing Record 19 of Set 3 | port alfred
# Processing Record 20 of Set 3 | rincon
# Processing Record 21 of Set 3 | kahului
# Processing Record 22 of Set 3 | dandong
# Processing Record 23 of Set 3 | hauterive
# Processing Record 24 of Set 3 | uray
# Processing Record 25 of Set 3 | plateros
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | flin flon
# Processing Record 28 of Set 3 | pisco
# Processing Record 29 of Set 3 | porto franco
# Processing Record 30 of Set 3 | shubarkuduk
# Processing Record 31 of Set 3 | sitka
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | paamiut
# Processing Record 35 of Set 3 | salalah
# Processing Record 36 of Set 3 | avarua
# Processing Record 37 of Set 3 | crib point
# Processing Record 38 of Set 3 | roald
# Processing Record 39 of Set 3 | vangaindrano
# Processing Record 40 of Set 3 | belfast
# Processing Record 41 of Set 3 | manica
# Processing Record 42 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 3 | el tigre
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | kapaa
# Processing Record 48 of Set 3 | jacareacanga
# Processing Record 49 of Set 3 | wuwei
# Processing Record 50 of Set 3 | port-gentil
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 2 of Set 4 | hermanus
# Processing Record 3 of Set 4 | chivay
# Processing Record 4 of Set 4 | kaduqli
# Processing Record 5 of Set 4 | back mountain
# Processing Record 6 of Set 4 | ixtapa
# Processing Record 7 of Set 4 | provideniya
# Processing Record 8 of Set 4 | qaqortoq
# Processing Record 9 of Set 4 | oktyabrskiy
# Processing Record 10 of Set 4 | mitsamiouli
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | busselton
# Processing Record 13 of Set 4 | tsentralnyy
# City not found. Skipping...
# Processing Record 14 of Set 4 | maniitsoq
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | nuuk
# Processing Record 18 of Set 4 | bonavista
# Processing Record 19 of Set 4 | ustrzyki dolne
# Processing Record 20 of Set 4 | juneau
# Processing Record 21 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | adzope
# Processing Record 24 of Set 4 | boende
# Processing Record 25 of Set 4 | half moon bay
# Processing Record 26 of Set 4 | mackay
# Processing Record 27 of Set 4 | asosa
# Processing Record 28 of Set 4 | westport
# Processing Record 29 of Set 4 | pavlovsk
# Processing Record 30 of Set 4 | geeste
# Processing Record 31 of Set 4 | jalu
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | navegantes
# Processing Record 34 of Set 4 | vallenar
# Processing Record 35 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 4 | palmer
# Processing Record 37 of Set 4 | umm lajj
# Processing Record 38 of Set 4 | atambua
# Processing Record 39 of Set 4 | strezhevoy
# Processing Record 40 of Set 4 | surt
# Processing Record 41 of Set 4 | pevek
# Processing Record 42 of Set 4 | el faiyum
# City not found. Skipping...
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | saint-pierre
# Processing Record 45 of Set 4 | leningradskiy
# Processing Record 46 of Set 4 | bluff
# Processing Record 47 of Set 4 | aden
# Processing Record 48 of Set 4 | anadyr
# Processing Record 49 of Set 4 | srednekolymsk
# Processing Record 50 of Set 4 | tynset
# Processing Record 1 of Set 5 | erenhot
# Processing Record 2 of Set 5 | sokolo
# Processing Record 3 of Set 5 | soligalich
# Processing Record 4 of Set 5 | baghdad
# Processing Record 5 of Set 5 | havelock
# Processing Record 6 of Set 5 | alofi
# Processing Record 7 of Set 5 | viedma
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | torbay
# Processing Record 10 of Set 5 | sergeyevka
# Processing Record 11 of Set 5 | trairi
# Processing Record 12 of Set 5 | bandarbeyla
# Processing Record 13 of Set 5 | ballina
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | bambous virieux
# Processing Record 16 of Set 5 | gomel
# Processing Record 17 of Set 5 | meadville
# Processing Record 18 of Set 5 | port macquarie
# Processing Record 19 of Set 5 | dingle
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | shelburne
# Processing Record 22 of Set 5 | hithadhoo
# Processing Record 23 of Set 5 | road town
# Processing Record 24 of Set 5 | kedrovyy
# Processing Record 25 of Set 5 | am timan
# Processing Record 26 of Set 5 | le mee-sur-seine
# Processing Record 27 of Set 5 | ponta do sol
# Processing Record 28 of Set 5 | qaanaaq
# Processing Record 29 of Set 5 | collie
# Processing Record 30 of Set 5 | mayo
# Processing Record 31 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 5 | tasiilaq
# Processing Record 33 of Set 5 | silver city
# Processing Record 34 of Set 5 | lima
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | ostersund
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | airai
# Processing Record 39 of Set 5 | davila
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | mubende
# Processing Record 42 of Set 5 | lovozero
# Processing Record 43 of Set 5 | pochutla
# Processing Record 44 of Set 5 | sorland
# Processing Record 45 of Set 5 | cruz
# Processing Record 46 of Set 5 | san rafael
# Processing Record 47 of Set 5 | mangrol
# Processing Record 48 of Set 5 | bintulu
# Processing Record 49 of Set 5 | waverley
# Processing Record 50 of Set 5 | black river
# Processing Record 1 of Set 6 | porto nacional
# Processing Record 2 of Set 6 | riyadh
# Processing Record 3 of Set 6 | markova
# Processing Record 4 of Set 6 | sohag
# Processing Record 5 of Set 6 | totness
# Processing Record 6 of Set 6 | udaipura
# Processing Record 7 of Set 6 | dzheguta
# Processing Record 8 of Set 6 | te anau
# Processing Record 9 of Set 6 | nanakuli
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | charlestown
# Processing Record 12 of Set 6 | maldonado
# Processing Record 13 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 6 | askim
# Processing Record 15 of Set 6 | naze
# Processing Record 16 of Set 6 | new port richey
# Processing Record 17 of Set 6 | nicoya
# Processing Record 18 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 6 | oloron-sainte-marie
# Processing Record 20 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 6 | hasaki
# Processing Record 22 of Set 6 | tilichiki
# Processing Record 23 of Set 6 | komsomolskiy
# Processing Record 24 of Set 6 | vardo
# Processing Record 25 of Set 6 | buedu
# Processing Record 26 of Set 6 | sao filipe
# Processing Record 27 of Set 6 | saint anthony
# Processing Record 28 of Set 6 | wilkie
# Processing Record 29 of Set 6 | champasak
# Processing Record 30 of Set 6 | nogliki
# Processing Record 31 of Set 6 | kamenka
# Processing Record 32 of Set 6 | malibu
# Processing Record 33 of Set 6 | coahuayana
# Processing Record 34 of Set 6 | pando
# Processing Record 35 of Set 6 | hervey bay
# Processing Record 36 of Set 6 | goya
# Processing Record 37 of Set 6 | lexington
# Processing Record 38 of Set 6 | mahajanga
# Processing Record 39 of Set 6 | foz do iguacu
# Processing Record 40 of Set 6 | naron
# Processing Record 41 of Set 6 | mayor pablo lagerenza
# Processing Record 42 of Set 6 | korla
# Processing Record 43 of Set 6 | inuvik
# Processing Record 44 of Set 6 | davidson
# Processing Record 45 of Set 6 | progreso
# Processing Record 46 of Set 6 | college
# Processing Record 47 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 6 | vernon
# Processing Record 49 of Set 6 | saundatti yellamma
# City not found. Skipping...
# Processing Record 50 of Set 6 | bururi
# Processing Record 1 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 7 | athni
# Processing Record 3 of Set 7 | udachnyy
# Processing Record 4 of Set 7 | broome
# Processing Record 5 of Set 7 | mar del plata
# Processing Record 6 of Set 7 | port blair
# Processing Record 7 of Set 7 | marsh harbour
# Processing Record 8 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 7 | mandeville
# Processing Record 10 of Set 7 | singaraja
# Processing Record 11 of Set 7 | constitucion
# Processing Record 12 of Set 7 | farafangana
# Processing Record 13 of Set 7 | takaungu
# Processing Record 14 of Set 7 | glubokoe
# City not found. Skipping...
# Processing Record 15 of Set 7 | san alberto
# Processing Record 16 of Set 7 | karema
# Processing Record 17 of Set 7 | kavaratti
# Processing Record 18 of Set 7 | rawson
# Processing Record 19 of Set 7 | havre-saint-pierre
# Processing Record 20 of Set 7 | high level
# Processing Record 21 of Set 7 | ambatofinandrahana
# Processing Record 22 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 7 | gulu
# Processing Record 24 of Set 7 | hurghada
# Processing Record 25 of Set 7 | guerrero negro
# Processing Record 26 of Set 7 | palu
# Processing Record 27 of Set 7 | geraldton
# Processing Record 28 of Set 7 | tuatapere
# Processing Record 29 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 7 | lithakia
# Processing Record 31 of Set 7 | albury
# Processing Record 32 of Set 7 | bonthe
# Processing Record 33 of Set 7 | encantado
# Processing Record 34 of Set 7 | el alto
# Processing Record 35 of Set 7 | valentin gomez farias
# Processing Record 36 of Set 7 | karratha
# Processing Record 37 of Set 7 | faanui
# Processing Record 38 of Set 7 | ranau
# Processing Record 39 of Set 7 | dindori
# Processing Record 40 of Set 7 | inhambane
# Processing Record 41 of Set 7 | poum
# Processing Record 42 of Set 7 | port hawkesbury
# Processing Record 43 of Set 7 | trenggalek
# Processing Record 44 of Set 7 | victor harbor
# Processing Record 45 of Set 7 | vanino
# Processing Record 46 of Set 7 | aswan
# Processing Record 47 of Set 7 | plettenberg bay
# Processing Record 48 of Set 7 | lumeje
# Processing Record 49 of Set 7 | port moresby
# Processing Record 50 of Set 7 | salto
# Processing Record 1 of Set 8 | lasa
# Processing Record 2 of Set 8 | stokmarknes
# Processing Record 3 of Set 8 | ridgecrest
# Processing Record 4 of Set 8 | bathurst
# Processing Record 5 of Set 8 | wanning
# Processing Record 6 of Set 8 | barranca
# Processing Record 7 of Set 8 | yanam
# Processing Record 8 of Set 8 | takoradi
# Processing Record 9 of Set 8 | port hedland
# Processing Record 10 of Set 8 | ambon
# Processing Record 11 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 8 | isangel
# Processing Record 13 of Set 8 | gornopravdinsk
# Processing Record 14 of Set 8 | kiunga
# Processing Record 15 of Set 8 | bongandanga
# Processing Record 16 of Set 8 | abalak
# Processing Record 17 of Set 8 | klaksvik
# Processing Record 18 of Set 8 | cockburn town
# Processing Record 19 of Set 8 | ulladulla
# Processing Record 20 of Set 8 | turukhansk
# Processing Record 21 of Set 8 | luau
# Processing Record 22 of Set 8 | ostrovnoy
# Processing Record 23 of Set 8 | salym
# Processing Record 24 of Set 8 | terra rica
# Processing Record 25 of Set 8 | soyo
# Processing Record 26 of Set 8 | navrongo
# Processing Record 27 of Set 8 | laguna
# Processing Record 28 of Set 8 | khatanga
# Processing Record 29 of Set 8 | manacor
# Processing Record 30 of Set 8 | mortka
# Processing Record 31 of Set 8 | ribeira grande
# Processing Record 32 of Set 8 | awbari
# Processing Record 33 of Set 8 | labuhan
# Processing Record 34 of Set 8 | hualmay
# Processing Record 35 of Set 8 | amahai
# Processing Record 36 of Set 8 | akyab
# Processing Record 37 of Set 8 | sao jose da coroa grande
# Processing Record 38 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 8 | kamakwie
# Processing Record 40 of Set 8 | cabo san lucas
# Processing Record 41 of Set 8 | tsumeb
# Processing Record 42 of Set 8 | biskamzha
# Processing Record 43 of Set 8 | mamedkala
# Processing Record 44 of Set 8 | kollumerland
# City not found. Skipping...
# Processing Record 45 of Set 8 | dunedin
# Processing Record 46 of Set 8 | samana
# Processing Record 47 of Set 8 | grindavik
# Processing Record 48 of Set 8 | aranos
# Processing Record 49 of Set 8 | lompoc
# Processing Record 50 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 9 | iracoubo
# Processing Record 2 of Set 9 | burica
# City not found. Skipping...
# Processing Record 3 of Set 9 | la ronge
# Processing Record 4 of Set 9 | kirakira
# Processing Record 5 of Set 9 | beira
# Processing Record 6 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 7 of Set 9 | vesoul
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | sept-iles
# Processing Record 10 of Set 9 | souillac
# Processing Record 11 of Set 9 | new baltimore
# Processing Record 12 of Set 9 | imbituba
# Processing Record 13 of Set 9 | gore
# Processing Record 14 of Set 9 | marfino
# Processing Record 15 of Set 9 | vaitape
# Processing Record 16 of Set 9 | dryden
# Processing Record 17 of Set 9 | guatire
# Processing Record 18 of Set 9 | la huacana
# Processing Record 19 of Set 9 | pitimbu
# Processing Record 20 of Set 9 | jiamusi
# Processing Record 21 of Set 9 | coihaique
# Processing Record 22 of Set 9 | alcudia
# Processing Record 23 of Set 9 | revda
# Processing Record 24 of Set 9 | fare
# Processing Record 25 of Set 9 | shirokiy
# Processing Record 26 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 27 of Set 9 | marawi
# Processing Record 28 of Set 9 | hamilton
# Processing Record 29 of Set 9 | fort wellington
# Processing Record 30 of Set 9 | churapcha
# Processing Record 31 of Set 9 | okha
# Processing Record 32 of Set 9 | muros
# Processing Record 33 of Set 9 | luderitz
# Processing Record 34 of Set 9 | lake havasu city
# Processing Record 35 of Set 9 | najran
# Processing Record 36 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 37 of Set 9 | edea
# Processing Record 38 of Set 9 | bayan
# Processing Record 39 of Set 9 | zainsk
# Processing Record 40 of Set 9 | bijie
# Processing Record 41 of Set 9 | santa rosa
# Processing Record 42 of Set 9 | marrakesh
# Processing Record 43 of Set 9 | riberalta
# Processing Record 44 of Set 9 | yining
# Processing Record 45 of Set 9 | shimoda
# Processing Record 46 of Set 9 | skibbereen
# Processing Record 47 of Set 9 | krasnoselkup
# Processing Record 48 of Set 9 | sabzevar
# Processing Record 49 of Set 9 | zhangye
# Processing Record 50 of Set 9 | homer
# Processing Record 1 of Set 10 | aasiaat
# Processing Record 2 of Set 10 | grand gaube
# Processing Record 3 of Set 10 | saint george
# Processing Record 4 of Set 10 | bondoukou
# Processing Record 5 of Set 10 | wana
# Processing Record 6 of Set 10 | yar-sale
# Processing Record 7 of Set 10 | tabou
# Processing Record 8 of Set 10 | camacha
# Processing Record 9 of Set 10 | talcahuano
# Processing Record 10 of Set 10 | ayr
# Processing Record 11 of Set 10 | mayari
# City not found. Skipping...
# Processing Record 12 of Set 10 | namibe
# Processing Record 13 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 10 | pala
# Processing Record 16 of Set 10 | paciran
# Processing Record 17 of Set 10 | itarema
# Processing Record 18 of Set 10 | westerland
# Processing Record 19 of Set 10 | flinders
# Processing Record 20 of Set 10 | gamba
# Processing Record 21 of Set 10 | evensk
# Processing Record 22 of Set 10 | araouane
# Processing Record 23 of Set 10 | alyangula
# Processing Record 24 of Set 10 | keetmanshoop
# Processing Record 25 of Set 10 | napanee
# Processing Record 26 of Set 10 | yekepa
# Processing Record 27 of Set 10 | mount isa
# Processing Record 28 of Set 10 | chatham
# Processing Record 29 of Set 10 | erseke
# Processing Record 30 of Set 10 | los alamos
# Processing Record 31 of Set 10 | batemans bay
# Processing Record 32 of Set 10 | vanimo
# Processing Record 33 of Set 10 | damietta
# Processing Record 34 of Set 10 | ada
# Processing Record 35 of Set 10 | esperance
# Processing Record 36 of Set 10 | puerto escondido
# Processing Record 37 of Set 10 | san vicente
# Processing Record 38 of Set 10 | axim
# Processing Record 39 of Set 10 | waitati
# Processing Record 40 of Set 10 | port hardy
# Processing Record 41 of Set 10 | fomboni
# Processing Record 42 of Set 10 | santa maria
# Processing Record 43 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 10 | padang
# Processing Record 45 of Set 10 | monrovia
# Processing Record 46 of Set 10 | codrington
# Processing Record 47 of Set 10 | umm kaddadah
# Processing Record 48 of Set 10 | brigantine
# Processing Record 49 of Set 10 | kudahuvadhoo
# Processing Record 50 of Set 10 | russell
# Processing Record 1 of Set 11 | calama
# Processing Record 2 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 3 of Set 11 | gigmoto
# Processing Record 4 of Set 11 | marienburg
# Processing Record 5 of Set 11 | jiayuguan
# Processing Record 6 of Set 11 | portree
# Processing Record 7 of Set 11 | bacolod
# Processing Record 8 of Set 11 | farah
# Processing Record 9 of Set 11 | batagay-alyta
# Processing Record 10 of Set 11 | toamasina
# Processing Record 11 of Set 11 | tura
# Processing Record 12 of Set 11 | agnibilekrou
# Processing Record 13 of Set 11 | cayenne
# Processing Record 14 of Set 11 | samfya
# Processing Record 15 of Set 11 | broken hill
# Processing Record 16 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 11 | panama city
# Processing Record 18 of Set 11 | nan
# Processing Record 19 of Set 11 | kiruna
# Processing Record 20 of Set 11 | wamba
# Processing Record 21 of Set 11 | deputatskiy
# Processing Record 22 of Set 11 | parras
# City not found. Skipping...
# Processing Record 23 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 11 | pandan
# Processing Record 25 of Set 11 | clyde river
# Processing Record 26 of Set 11 | goderich
# Processing Record 27 of Set 11 | buenavista
# Processing Record 28 of Set 11 | ahipara
# Processing Record 29 of Set 11 | auki
# Processing Record 30 of Set 11 | maple creek
# Processing Record 31 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 32 of Set 11 | manokwari
# Processing Record 33 of Set 11 | port augusta
# Processing Record 34 of Set 11 | winnemucca
# Processing Record 35 of Set 11 | togur
# Processing Record 36 of Set 11 | puerto gaitan
# Processing Record 37 of Set 11 | dekar
# Processing Record 38 of Set 11 | sao joao da barra
# Processing Record 39 of Set 11 | bushehr
# Processing Record 40 of Set 11 | padilla
# Processing Record 41 of Set 11 | panaba
# Processing Record 42 of Set 11 | taltal
# Processing Record 43 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 11 | tortoli
# Processing Record 45 of Set 11 | alta
# Processing Record 46 of Set 11 | miri
# Processing Record 47 of Set 11 | belmonte
# Processing Record 48 of Set 11 | spencer
# Processing Record 49 of Set 11 | magan
# Processing Record 50 of Set 11 | petrykiv
# Processing Record 1 of Set 12 | cidreira
# Processing Record 2 of Set 12 | buta
# Processing Record 3 of Set 12 | calvinia
# Processing Record 4 of Set 12 | hagi
# Processing Record 5 of Set 12 | santa cruz
# Processing Record 6 of Set 12 | aojiang
# Processing Record 7 of Set 12 | champerico
# Processing Record 8 of Set 12 | chaa-khol
# City not found. Skipping...
# Processing Record 9 of Set 12 | muisne
# Processing Record 10 of Set 12 | cocobeach
# Processing Record 11 of Set 12 | coquimbo
# Processing Record 12 of Set 12 | angra
# City not found. Skipping...
# Processing Record 13 of Set 12 | anchorage
# Processing Record 14 of Set 12 | ust-kuyga
# Processing Record 15 of Set 12 | haines junction
# Processing Record 16 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 17 of Set 12 | nikolskoye
# Processing Record 18 of Set 12 | japura
# Processing Record 19 of Set 12 | gao
# Processing Record 20 of Set 12 | lata
# Processing Record 21 of Set 12 | george
# Processing Record 22 of Set 12 | buraydah
# Processing Record 23 of Set 12 | verkhnevilyuysk
# Processing Record 24 of Set 12 | aksu
# Processing Record 25 of Set 12 | cururupu
# Processing Record 26 of Set 12 | blacksburg
# Processing Record 27 of Set 12 | la rioja
# Processing Record 28 of Set 12 | abu dhabi
# Processing Record 29 of Set 12 | qingan
# City not found. Skipping...
# Processing Record 30 of Set 12 | hearst
# Processing Record 31 of Set 12 | burnie
# Processing Record 32 of Set 12 | bagaha
# Processing Record 33 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 12 | nizhniy ingash
# Processing Record 35 of Set 12 | bilma
# Processing Record 36 of Set 12 | carhuamayo
# Processing Record 37 of Set 12 | iberia
# Processing Record 38 of Set 12 | whitehorse
# Processing Record 39 of Set 12 | emerald
# Processing Record 40 of Set 12 | saint-francois
# Processing Record 41 of Set 12 | oxelosund
# Processing Record 42 of Set 12 | bud
# Processing Record 43 of Set 12 | varhaug
# Processing Record 44 of Set 12 | obo
# Processing Record 45 of Set 12 | portland
# Processing Record 46 of Set 12 | chicama
# Processing Record 47 of Set 12 | mana
# Processing Record 48 of Set 12 | mikhaylovka
# Processing Record 49 of Set 12 | cascais
# Processing Record 50 of Set 12 | toucheng
# Processing Record 1 of Set 13 | nabire
# Processing Record 2 of Set 13 | sao felix do xingu
# Processing Record 3 of Set 13 | tingrela
# City not found. Skipping...
# Processing Record 4 of Set 13 | santa isabel
# Processing Record 5 of Set 13 | hua hin
# Processing Record 6 of Set 13 | vilhena
# Processing Record 7 of Set 13 | ler
# Processing Record 8 of Set 13 | meulaboh
# Processing Record 9 of Set 13 | fez
# Processing Record 10 of Set 13 | makushino
# Processing Record 11 of Set 13 | general pico
# Processing Record 12 of Set 13 | kloulklubed
# Processing Record 13 of Set 13 | richards bay
# Processing Record 14 of Set 13 | boyolangu
# Processing Record 15 of Set 13 | ambilobe
# Processing Record 16 of Set 13 | loikaw
# Processing Record 17 of Set 13 | honningsvag
# Processing Record 18 of Set 13 | valparaiso
# Processing Record 19 of Set 13 | svetlogorsk
# Processing Record 20 of Set 13 | faya
# Processing Record 21 of Set 13 | kokkola
# Processing Record 22 of Set 13 | lentekhi
# Processing Record 23 of Set 13 | netrakona
# Processing Record 24 of Set 13 | touros
# Processing Record 25 of Set 13 | aklavik
# Processing Record 26 of Set 13 | beringovskiy
# Processing Record 27 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 28 of Set 13 | mari-turek
# Processing Record 29 of Set 13 | cozumel
# Processing Record 30 of Set 13 | trat
# Processing Record 31 of Set 13 | ocean city
# Processing Record 32 of Set 13 | madingou
# Processing Record 33 of Set 13 | sobolevo
# Processing Record 34 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 13 | lewistown
# Processing Record 36 of Set 13 | tongliao
# Processing Record 37 of Set 13 | ovsyanka
# Processing Record 38 of Set 13 | vila velha
# Processing Record 39 of Set 13 | seguela
# Processing Record 40 of Set 13 | makakilo city
# Processing Record 41 of Set 13 | priiskovyy
# Processing Record 42 of Set 13 | vanersborg
# Processing Record 43 of Set 13 | arman
# Processing Record 44 of Set 13 | moree
# Processing Record 45 of Set 13 | nara
# Processing Record 46 of Set 13 | penzance
# Processing Record 47 of Set 13 | yaqui
# Processing Record 48 of Set 13 | uralets
# Processing Record 49 of Set 13 | grand forks
# Processing Record 50 of Set 13 | morgan city
# Processing Record 1 of Set 14 | roswell
# Processing Record 2 of Set 14 | tim
# Processing Record 3 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 14 | diffa
# Processing Record 5 of Set 14 | iqaluit
# Processing Record 6 of Set 14 | ucluelet
# Processing Record 7 of Set 14 | satkhira
# Processing Record 8 of Set 14 | san miguel
# Processing Record 9 of Set 14 | pandamatenga
# Processing Record 10 of Set 14 | fairbanks
# Processing Record 11 of Set 14 | safaga
# Processing Record 12 of Set 14 | lakatoro
# Processing Record 13 of Set 14 | khandbari
# Processing Record 14 of Set 14 | jatibonico
# Processing Record 15 of Set 14 | nsanje
# Processing Record 16 of Set 14 | tolbazy
# Processing Record 17 of Set 14 | lac du bonnet
# Processing Record 18 of Set 14 | shache
# Processing Record 19 of Set 14 | floro
# Processing Record 20 of Set 14 | hitachi
# Processing Record 21 of Set 14 | himora
# City not found. Skipping...
# Processing Record 22 of Set 14 | asau
# Processing Record 23 of Set 14 | wenatchee
# Processing Record 24 of Set 14 | khilok
# Processing Record 25 of Set 14 | samarai
# Processing Record 26 of Set 14 | kochi
# Processing Record 27 of Set 14 | rizhao
# Processing Record 28 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 29 of Set 14 | los llanos de aridane
# Processing Record 30 of Set 14 | rapina
# Processing Record 31 of Set 14 | high prairie
# Processing Record 32 of Set 14 | ukiah
# Processing Record 33 of Set 14 | kollam
# Processing Record 34 of Set 14 | hoi an
# Processing Record 35 of Set 14 | ganzhou
# Processing Record 36 of Set 14 | galveston
# Processing Record 37 of Set 14 | arklow
# Processing Record 38 of Set 14 | coruripe
# Processing Record 39 of Set 14 | knysna
# Processing Record 40 of Set 14 | santo antonio
# Processing Record 41 of Set 14 | talnakh
# Processing Record 42 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 14 | sibolga
# Processing Record 44 of Set 14 | aktau
# Processing Record 45 of Set 14 | atar
# Processing Record 46 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 14 | haapu
# City not found. Skipping...
# Processing Record 48 of Set 14 | jiuquan
# Processing Record 49 of Set 14 | beyneu
# Processing Record 50 of Set 14 | yerbogachen
# Processing Record 1 of Set 15 | shar
# Processing Record 2 of Set 15 | olafsvik
# Processing Record 3 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 4 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 15 | kruisfontein
# Processing Record 7 of Set 15 | yaan
# Processing Record 8 of Set 15 | bondo
# Processing Record 9 of Set 15 | sorong
# Processing Record 10 of Set 15 | rafaela
# Processing Record 11 of Set 15 | lubbock
# Processing Record 12 of Set 15 | caravelas
# Processing Record 13 of Set 15 | micheweni
# Processing Record 14 of Set 15 | zabid
# Processing Record 15 of Set 15 | asfi
# Processing Record 16 of Set 15 | floriano
# Processing Record 17 of Set 15 | ampanihy
# Processing Record 18 of Set 15 | jiaozhou
# Processing Record 19 of Set 15 | mecca
# Processing Record 20 of Set 15 | kutum
# Processing Record 21 of Set 15 | mitu
# Processing Record 22 of Set 15 | bekessamson
# Processing Record 23 of Set 15 | tigzirt
# Processing Record 24 of Set 15 | tual
# Processing Record 25 of Set 15 | tromso
# Processing Record 26 of Set 15 | nizwa
# Processing Record 27 of Set 15 | paidha
# Processing Record 28 of Set 15 | golden
# Processing Record 29 of Set 15 | kieta
# Processing Record 30 of Set 15 | mount gambier
# Processing Record 31 of Set 15 | kilindoni
# Processing Record 32 of Set 15 | bredy
# Processing Record 33 of Set 15 | okitipupa
# Processing Record 34 of Set 15 | gold coast
# Processing Record 35 of Set 15 | polyarnyy
# Processing Record 36 of Set 15 | veraval
# Processing Record 37 of Set 15 | ashland
# Processing Record 38 of Set 15 | cabedelo
# Processing Record 39 of Set 15 | toktogul
# Processing Record 40 of Set 15 | mareeba
# Processing Record 41 of Set 15 | pedasi
# Processing Record 42 of Set 15 | yabelo
# Processing Record 43 of Set 15 | zyryanka
# Processing Record 44 of Set 15 | huanren
# Processing Record 45 of Set 15 | aquin
# Processing Record 46 of Set 15 | nakamura
# Processing Record 47 of Set 15 | zhigansk
# Processing Record 48 of Set 15 | bambanglipuro
# Processing Record 49 of Set 15 | sychevka
# Processing Record 50 of Set 15 | sarangani
# Processing Record 1 of Set 16 | shingu
# Processing Record 2 of Set 16 | sheltozero
# Processing Record 3 of Set 16 | coffs harbour
# Processing Record 4 of Set 16 | uwayl
# City not found. Skipping...
# Processing Record 5 of Set 16 | bubaque
# Processing Record 6 of Set 16 | marshfield
# Processing Record 7 of Set 16 | bima
# Processing Record 8 of Set 16 | montepuez
# Processing Record 9 of Set 16 | gouyave
# Processing Record 10 of Set 16 | male
# Processing Record 11 of Set 16 | altamont
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 693

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Bathsheba  13.2167  -59.5167     77.61        69          75       17.27
# 1        Hofn  64.2539  -15.2082     31.93        89         100       17.43
# 2      Hobart -42.8794  147.3294     56.26        86          75        9.22
# 3  Oranjemund -28.5500   16.4333     67.64        76          68       16.78
# 4      Cairns -16.9167  145.7667     92.07        70         100       10.36
# 5     Rikitea -23.1203 -134.9692     79.12        69           0       15.37
# 6      Plerin  48.5425   -2.7798     46.72        80         100        4.61
# 7  Butaritari   3.0707  172.7902     80.67        78         100       20.71
# 8  Saint-Tite  46.7334  -72.5658      5.23       100          99        1.92
# 9       Wajid   3.8093   43.2471     88.79        29          70       12.21
#
#   Country      Description
# 0      BB    broken clouds
# 1      IS       light snow
# 2      AU       light rain
# 3      NA    broken clouds
# 4      AU  overcast clouds
# 5      PF        clear sky
# 6      FR  overcast clouds
# 7      KI       light rain
# 8      CA  overcast clouds
# 9      SO    broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"] 

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Bathsheba      BB  13.2167  -59.5167     77.61        69          75
# 1        Hofn      IS  64.2539  -15.2082     31.93        89         100
# 2      Hobart      AU -42.8794  147.3294     56.26        86          75
# 3  Oranjemund      NA -28.5500   16.4333     67.64        76          68
# 4      Cairns      AU -16.9167  145.7667     92.07        70         100
# 5     Rikitea      PF -23.1203 -134.9692     79.12        69           0
# 6      Plerin      FR  48.5425   -2.7798     46.72        80         100
# 7  Butaritari      KI   3.0707  172.7902     80.67        78         100
# 8  Saint-Tite      CA  46.7334  -72.5658      5.23       100          99
# 9       Wajid      SO   3.8093   43.2471     88.79        29          70
#
#    Wind Speed      Description
# 0       17.27    broken clouds
# 1       17.43       light snow
# 2        9.22       light rain
# 3       16.78    broken clouds
# 4       10.36  overcast clouds
# 5       15.37        clear sky
# 6        4.61  overcast clouds
# 7       20.71       light rain
# 8        1.92  overcast clouds
# 9       12.21    broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
